# %%
####构建ITR树其中包含tokenization部分####
import nltk
import torch
import torch.nn as nn
import math
import torch.optim as optim
import json
import re
import csv
import pymongo
import psutil
import os
import sys

from nltk.tokenize import word_tokenize
from torch.utils.data import Dataset, DataLoader
from collections import defaultdict
from itertools import count
from sklearn.model_selection import train_test_split
from pymongo import MongoClient

# %%
class TreeNode:
    def __init__(self, data, tag):
        self.data = data
        self.tag= tag
        self.children = []
        self.embedding = []
        self.deep = 0
    def clear(self):
        self.data = None
        self.children = []

# 给树添加边的信息
def add_edge(parent, child, edge_data):
    parent.children.append((child, edge_data))
    

def build_ITR_tree(Seqsstate, Seqslog, Seqscall_1):
    # 创建节点字典，将调用ID映射到相应的树节点
    call_id_to_node = {}
    
    # 初始化根节点
    root = TreeNode(Seqscall_1[0][0],'call')
    call_id_to_node[Seqscall_1[0][0]] = root
    root.data = Seqscall_1[1][0]
    root.deep = 0
    # 遍历调用序列以构建树
    for i in range(1, len(Seqscall_1[0])):
        call = Seqscall_1[0][i]
        parent_call = Seqscall_1[0][i - 1]
        parent_node = call_id_to_node[parent_call]
        call_node = TreeNode(call,'call')
        call_node.data = Seqscall_1[1][i]
        call_node.deep = parent_node.deep +1
        # 添加调用之间的边信息
        add_edge(parent_node, call_node, f"Call {parent_call} -> {call}")
        
        call_id_to_node[call] = call_node
    
    # 遍历状态跟踪以构建树
    i = 0
    for state_call in Seqsstate[0]:
        state_node = TreeNode(state_call,'state')
        parent_call = Seqsstate[1][state_call]
        parent_node = call_id_to_node[parent_call]
        
        # 添加状态与调用之间的边信息
        add_edge(parent_node, state_node, f"State {parent_call} -> {state_call}")
        state_node.data = Seqsstate[2][i]
        state_node.deep = parent_node.deep + 1
        i = i+1

    # 遍历日志跟踪以构建树
    i = 0
    for log_call in Seqslog[0]:
        log_node = TreeNode(log_call,'log')
        parent_call = Seqslog[1][log_call]
        parent_node = call_id_to_node[parent_call]
        
        # 添加日志与调用之间的边信息
        add_edge(parent_node, log_node, f"Log {parent_call} -> {log_call}")
        log_node.data = Seqslog[2][i]
        log_node.deep = parent_node.deep + 1
        i = i+1

    return root
####Tokenization部分####
def tokenize_text(text,node_tag):
    if isinstance(text, str):
        # 使用逗号和下划线作为分隔符
        tokens = re.split(r'[,]', text)
        # 仅保留长度大于1的单词
        tokens = [token.strip() for token in tokens if len(token) > 1]
        # 添加[START]和[END]标记
        tokens = ['[START]'] + [f'[{node_tag.upper()}]'] + tokens + ['[END]']
        
        # 对call_trace中in和out部分添加[OUTs]和[INs]标签
        if  node_tag == 'call':
            in_indices = [i for i, token in enumerate(tokens) if 'input_type' in token]
            out_indices = [i for i, token in enumerate(tokens) if 'output_type' in token]
            
            # 在第一个 input_type 之前插入 [INs]
            if in_indices:
                tokens = tokens[:in_indices[0]] + ['[INs]'] + tokens[in_indices[0]:]
            
            # 在第一个 output_type 之前插入 [OUTs]
            if out_indices:
                tokens = tokens[:out_indices[0] + 1] + ['[OUTs]'] + tokens[out_indices[0] + 1:]
        
        return tokens
    else:
        return text

def tokenize_tree(root):
    # 递归地对树的每个节点进行标记化
    root.data = tokenize_text(root.data,root.tag)
    for child, edge_data in root.children:
        child.data = tokenize_text(child.data,child.tag)
        tokenize_tree(child)

# 构建词汇表
class Vocabulary:
    def __init__(self):
        self.word_to_index = {}
        self.index_to_word = {}
        self.oov_index = 0  # 假设 0 是 [OOV] 的索引
        self.word_to_index['[OOV]'] = self.oov_index
        self.index_to_word[self.oov_index] = '[OOV]'
        self.index = 1

    def add_word(self, word):
        if word not in self.word_to_index:
            self.word_to_index[word] = self.index
            self.index_to_word[self.index] = word
            self.index += 1

    def get_index(self, word):
        # 获取单词的索引
        if word in self.word_to_index:
            return self.word_to_index[word]
        else:
            # 处理词汇表之外的单词
            return self.word_to_index['[OOV]']
            
def build_vocabulary(root, vocabulary):
    for token in root.data:
            vocabulary.add_word(token)
    # 递归地添加每个节点的单词到词汇表
    for child, edge_data in root.children:
        for token in child.data:
            vocabulary.add_word(token)
        build_vocabulary(child, vocabulary)
#转化为词向量
class WordEmbedding(nn.Module):
    def __init__(self, vocab_size, d_model):
        super(WordEmbedding, self).__init__()
        self.d_model = d_model
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.embed = self.embedding

    def forward(self, x):
        return self.embed(x) * (self.d_model ** 0.5)
#生成动态的position embedding
def generate_position_embedding(seq_len, d_model):
    position = torch.arange(0, seq_len).unsqueeze(1).float()
    div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
    pe = torch.zeros(seq_len, d_model)
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe.unsqueeze(0)
#继续添加上计算节点的相对位置信息
#计算节点的相对深度
def depth(node):
    if not node:
        return 0
    d = 0
    for child, edge_data in node.children:
        d = max(d, depth(child) + 1)
    return d
def build_tree_position_embedding(root, d_model):
    max_depth = depth(root)
    position_embedding = torch.zeros(max_depth+1, d_model)
    for i in range(max_depth):
        for j in range(d_model):
            position_embedding[i][j] = math.sin(i / (10000 ** (2 * j / d_model)))
    return position_embedding

#递归调用转化结点-生成初始的work embedding
def build_WordEmbedding(root, vocabulary, vocab_size, d_model):
    embedding_layer = WordEmbedding(vocab_size, d_model)
    tensor_from_add = torch.rand(1, d_model).unsqueeze(0)  # 对不同from要加上的形状为 (1, 512) 的张量
    tensor_to_add = -tensor_from_add                       # 对不同to要加上的张量#在此处对其加上tree position信息
    tree_position_embedding = build_tree_position_embedding(root,d_model)   #生成对应的tree_position
    tokens = root.data
    token_indices = torch.tensor([[vocabulary.get_index(token) for token in tokens]], dtype=torch.long)
    embeddings = embedding_layer(token_indices)
    root.embedding = embeddings     ##此处完成基础的token embedding
    #获取动态生成的position embedding
    max_len = len(tokens)
    position_embedding = generate_position_embedding(max_len, d_model)
    #将词向量和 position embedding 相加
    embeddings = embeddings + position_embedding
    root.embedding = embeddings     ##此处完成加上root信息后的的token embeddin
    ##在此处对其加上src信息
    if(root.tag == 'call'):
        embeddings[0, 2, :] +=  tensor_from_add.squeeze().expand_as(embeddings[0, 2, :])
        embeddings[0, 3, :] +=  tensor_to_add.squeeze().expand_as(embeddings[0, 3, :])
    root.embedding = embeddings     #此处完成了对call trace中的form和to加上信息的操作
    root.embedding = root.embedding.reshape(-1, root.embedding.size(-1))
    def trave(root, vocabulary, vocab_size, d_model):
        for child, edge_data in root.children:
                    
            #测试内存代码
            process = psutil.Process(os.getpid())
            memory_info = process.memory_info()
            # 输出以兆字节为单位的内存占用情况
            print(f"构建embedding child开始: {memory_info.rss / (1024 * 1024):.2f} MB")

            tokens = child.data
            token_indices = torch.tensor([[vocabulary.get_index(token) for token in tokens]], dtype=torch.long)
            embeddings = embedding_layer(token_indices)
            child.embedding = embeddings    #此处完成基础的token embedding
            #获取动态生成的position embedding
            max_len = len(tokens)
            position_embedding = generate_position_embedding(max_len, d_model)
            #将词向量和 position embedding 相加
            embeddings = embeddings + position_embedding
            child.embedding = embeddings     ##此处完成加上root信息后的的token embeddin
            ##在此处对其加上src信息
            if(child.tag == 'call'):
                embeddings[0, 2, :] += tensor_from_add.squeeze().expand_as(embeddings[0, 2, :])
                embeddings[0, 3, :] += tensor_to_add.squeeze().expand_as(embeddings[0, 3, :])
            child.embedding = embeddings
            #加上tree position
            child.embedding += tree_position_embedding[child.deep,:].unsqueeze(0)
            child.embedding = child.embedding.reshape(-1, child.embedding.size(-1))
            trave(child, vocabulary, vocab_size, d_model)

            #测试内存代码
            process = psutil.Process(os.getpid())
            memory_info = process.memory_info()
            # 输出以兆字节为单位的内存占用情况
            print(f"构建embedding child结束: {memory_info.rss / (1024 * 1024):.2f} MB")

    trave(root, vocabulary, vocab_size, d_model)

# 自定义数据集类
class CustomDataset(Dataset):
    def __init__(self, data):
        self.data = data
        self.max_seq_length = max(len(node.embedding) for node in data)

    def __len__(self):
        return len(self.data)

    def pad_sequence(self, sequence, max_length):
        # 如果序列长度小于最大长度，进行填充
        if len(sequence) < max_length:
            padding_size = max_length - len(sequence)
            padding = torch.zeros(padding_size, sequence.size(-1))  # 假设最后一维是embedding的维度
            sequence = torch.cat([sequence, padding], dim=0)
        return sequence

    def __getitem__(self, idx):
        # 获取节点embedding
        node_embedding = self.data[idx].embedding
        # 使用 pad_sequence 方法填充序列到最大长度
        padded_embedding = self.pad_sequence(node_embedding, self.max_seq_length)
        # 返回节点嵌入信息作为输入和输出型
        return padded_embedding, padded_embedding

# Transformer 编码器模型
class TransformerEncoderModel(nn.Module):
    def __init__(self, embedding_layer,vocab_size,d_model, hidden_size, num_heads, num_layers):
        super(TransformerEncoderModel, self).__init__()
        self.embedding = embedding_layer
        self.encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model, num_heads, hidden_size), num_layers
        )
        self.output_layer = nn.Linear(d_model, vocab_size)


    def forward(self, x):
        x = self.encoder(x)
        x = self.output_layer(x)
        return x

# 创建数据集-递归方式
def traverse_tree(node, node_list):

    #测试内存代码
    process = psutil.Process(os.getpid())
    memory_info = process.memory_info()
    # 输出以兆字节为单位的内存占用情况
    print(f"构建数据集开始: {memory_info.rss / (1024 * 1024):.2f} MB")

    # 将当前节点加入列表
    node_list.append(node)

    
    #测试内存代码
    process = psutil.Process(os.getpid())
    memory_info = process.memory_info()
    # 输出以兆字节为单位的内存占用情况
    print(f"构建数据集结束: {memory_info.rss / (1024 * 1024):.2f} MB")

    # 递归遍历子节点
    for child, _ in node.children:
        traverse_tree(child, node_list)


#数据处理部分函数
def process_call_entry(call_entry, call_idx, Seqscall_1, Seqsstate_1, Seqslog_1, state_idx, log_idx):
    Seqscall_1[0].append(f't{call_idx}call')
    call_info = [f'{call_entry["call_from"]},{call_entry["call_to"]},{call_entry["call_function_name"]},{call_entry["call_gas"]},{call_entry["call_value"]}']

    for input_entry in call_entry["call_input"]:
        call_info.extend([f'{input_entry["call_input_type"]},{input_entry["call_input_value"]}'])

    for output_entry in call_entry["call_output"]:
        call_info.extend([f'{output_entry["call_output_type"]},{output_entry["call_output_value"]}'])

    Seqscall_1[1].extend([','.join(call_info)])

    for state_entry in call_entry["stata"]:
        Seqsstate_1[0].append(f't{state_idx}state')
        Seqsstate_1[1][f't{state_idx}state'] = f't{call_idx}call'
        state_info = [f'{state_entry["tag"]},{state_entry["key"]},{state_entry["value"]}']
        Seqsstate_1[2].extend(state_info)
        state_idx += 1

    for log_entry in call_entry["log"]:
        Seqslog_1[0].append(f't{log_idx}log')
        Seqslog_1[1][f't{log_idx}log'] = f't{call_idx}call'
        log_info = [f'{log_entry["contract_address"]},{log_entry["event_hash"]}']

        for l_d_entry in log_entry["data"]:
            log_info.extend([f'{l_d_entry["type"]},{l_d_entry["value"]}'])

        Seqslog_1[2].extend(log_info)
        log_idx += 1
    return state_idx,log_idx

def build_tree_and_vocabulary(Seqsstate_1, Seqslog_1, Seqscall_1,vocabulary):
    root_node = build_ITR_tree(Seqsstate_1, Seqslog_1, Seqscall_1)
    tokenize_tree(root_node)
    
    build_vocabulary(root_node, vocabulary)
    
    return root_node, vocabulary

def process_entry(entry):
    Seqscall_1 = [[],[]]
    Seqsstate_1 = [[],{},[]]
    Seqslog_1 = [[],{},[]]

    state_idx = 0
    log_idx = 0
    
    for call_idx, call_entry in enumerate(entry["call"]):
       state_idx,log_idx = process_call_entry(call_entry, call_idx, Seqscall_1, Seqsstate_1, Seqslog_1, state_idx, log_idx)

    return Seqsstate_1, Seqslog_1, Seqscall_1

# %%
#连接数据库构建
client = MongoClient('mongodb://b515:sqwUiJGHYQTikv6z@10.12.46.33:27018/?authMechanism=DEFAULT')
dbtest = client["geth"]
collection = dbtest.get_collection("cnz_output")
# 定义游标（每次拉取batch个数据）
cursor = collection.find().batch_size(2000)
count = 2 # 一共处理多少次
limit = 1000 # 每次预处理limit个数据
vocabulary = Vocabulary()
for i in range(count):
    tree_node_list=[]
    cnt = 0
    for idx, entry in enumerate(cursor):
        Seqsstate_1, Seqslog_1, Seqscall_1 = process_entry(entry)
        root_node, vocabulary = build_tree_and_vocabulary(Seqsstate_1, Seqslog_1, Seqscall_1,vocabulary)    
        vocab_size = vocabulary.index + 1
        d_model = 64
        build_WordEmbedding(root_node, vocabulary, vocab_size, d_model)
        traverse_tree(root_node, tree_node_list)
        
        #测试内存代码
        process = psutil.Process(os.getpid())
        memory_info = process.memory_info()
        # 输出以兆字节为单位的内存占用情况
        print(f"traverse_tree: Memory Usage: {memory_info.rss / (1024 * 1024):.2f} MB")
        Seqscall_1.clear()
        Seqslog_1.clear()
        Seqscall_1.clear()
        # 每次预处理limit个数据
        cnt+=1
        if cnt==limit:
            cnt = 0
            break
    #测试内存代码
    process = psutil.Process(os.getpid())
    memory_info = process.memory_info()
    # 输出以兆字节为单位的内存占用情况
    print(f"Memory Usage最终: {memory_info.rss / (1024 * 1024):.2f} MB")
    print(f'最终size：{vocab_size}')
    #print(vocabulary.index_to_word)
    #划分数据集训练集
    train_sequences, val_sequences = train_test_split(tree_node_list, test_size=0.1, random_state=42)
    train_data = CustomDataset(train_sequences)
    val_data = CustomDataset(val_sequences)
    #创建数据加载器
    batch_size = 64
    train_data_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    val_data_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True)
# Out:
# 构建embedding child开始: 499.40 MB
# 构建embedding child结束: 499.41 MB
# 构建数据集开始: 499.41 MB
# 构建数据集结束: 499.41 MB
# 构建数据集开始: 499.41 MB
# 构建数据集结束: 499.41 MB
# traverse_tree: Memory Usage: 499.41 MB
# 构建embedding child开始: 499.41 MB
# 构建embedding child结束: 499.41 MB
# 构建embedding child开始: 499.41 MB
# 构建embedding child结束: 499.41 MB
# 构建embedding child开始: 499.41 MB
# 构建embedding child结束: 499.41 MB
# 构建embedding child开始: 499.41 MB
# 构建embedding child结束: 499.41 MB
# 构建embedding child开始: 499.41 MB
# 构建embedding child结束: 499.41 MB
# 构建embedding child开始: 499.41 MB
# 构建embedding child结束: 499.41 MB
# 构建数据集开始: 499.41 MB
# 构建数据集结束: 499.41 MB
# 构建数据集开始: 499.41 MB
# 构建数据集结束: 499.41 MB
# 构建数据集开始: 499.41 MB
# 构建数据集结束: 499.41 MB
# 构建数据集开始: 499.41 MB
# 构建数据集结束: 499.41 MB
# 构建数据集开始: 499.41 MB
# 构建数据集结束: 499.41 MB
# 构建数据集开始: 499.41 MB
# 构建数据集结束: 499.41 MB
# 构建数据集开始: 499.41 MB
# 构建数据集结束: 499.41 MB
# traverse_tree: Memory Usage: 499.41 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建embedding child开始: 499.42 MB
# 构建embedding child结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# 构建数据集开始: 499.42 MB
# 构建数据集结束: 499.42 MB
# traverse_tree: Memory Usage: 499.42 MB
# 构建embedding child开始: 499.44 MB
# 构建embedding child结束: 499.44 MB
# 构建embedding child开始: 499.44 MB
# 构建embedding child结束: 499.44 MB
# 构建embedding child开始: 499.44 MB
# 构建embedding child结束: 499.44 MB
# 构建embedding child开始: 499.44 MB
# 构建embedding child结束: 499.44 MB
# 构建embedding child开始: 499.44 MB
# 构建embedding child结束: 499.44 MB
# 构建embedding child开始: 499.44 MB
# 构建embedding child结束: 499.44 MB
# 构建embedding child开始: 499.44 MB
# 构建embedding child结束: 499.44 MB
# 构建数据集开始: 499.44 MB
# 构建数据集结束: 499.44 MB
# 构建数据集开始: 499.44 MB
# 构建数据集结束: 499.44 MB
# 构建数据集开始: 499.44 MB
# 构建数据集结束: 499.44 MB
# 构建数据集开始: 499.44 MB
# 构建数据集结束: 499.44 MB
# 构建数据集开始: 499.44 MB
# 构建数据集结束: 499.44 MB
# 构建数据集开始: 499.44 MB
# 构建数据集结束: 499.44 MB
# 构建数据集开始: 499.44 MB
# 构建数据集结束: 499.44 MB
# 构建数据集开始: 499.44 MB
# 构建数据集结束: 499.44 MB
# traverse_tree: Memory Usage: 499.44 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child开始: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建embedding child结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# 构建数据集开始: 499.46 MB
# 构建数据集结束: 499.46 MB
# traverse_tree: Memory Usage: 499.46 MB
# 构建embedding child开始: 499.49 MB
# 构建embedding child结束: 499.49 MB
# 构建数据集开始: 499.49 MB
# 构建数据集结束: 499.49 MB
# 构建数据集开始: 499.49 MB
# 构建数据集结束: 499.49 MB
# traverse_tree: Memory Usage: 499.49 MB
# 构建embedding child开始: 499.50 MB
# 构建embedding child结束: 499.50 MB
# 构建embedding child开始: 499.50 MB
# 构建embedding child结束: 499.50 MB
# 构建embedding child开始: 499.50 MB
# 构建embedding child结束: 499.50 MB
# 构建embedding child开始: 499.50 MB
# 构建embedding child结束: 499.50 MB
# 构建embedding child开始: 499.50 MB
# 构建embedding child结束: 499.50 MB
# 构建embedding child开始: 499.50 MB
# 构建embedding child结束: 499.50 MB
# 构建数据集开始: 499.50 MB
# 构建数据集结束: 499.50 MB
# 构建数据集开始: 499.50 MB
# 构建数据集结束: 499.50 MB
# 构建数据集开始: 499.50 MB
# 构建数据集结束: 499.50 MB
# 构建数据集开始: 499.50 MB
# 构建数据集结束: 499.50 MB
# 构建数据集开始: 499.50 MB
# 构建数据集结束: 499.50 MB
# 构建数据集开始: 499.50 MB
# 构建数据集结束: 499.50 MB
# 构建数据集开始: 499.50 MB
# 构建数据集结束: 499.50 MB
# traverse_tree: Memory Usage: 499.50 MB
# 构建embedding child开始: 499.54 MB
# 构建embedding child结束: 499.54 MB
# 构建embedding child开始: 499.54 MB
# 构建embedding child结束: 499.54 MB
# 构建embedding child开始: 499.54 MB
# 构建embedding child结束: 499.54 MB
# 构建embedding child开始: 499.54 MB
# 构建embedding child结束: 499.54 MB
# 构建embedding child开始: 499.54 MB
# 构建embedding child结束: 499.54 MB
# 构建embedding child开始: 499.54 MB
# 构建embedding child结束: 499.54 MB
# 构建数据集开始: 499.54 MB
# 构建数据集结束: 499.54 MB
# 构建数据集开始: 499.54 MB
# 构建数据集结束: 499.54 MB
# 构建数据集开始: 499.54 MB
# 构建数据集结束: 499.54 MB
# 构建数据集开始: 499.54 MB
# 构建数据集结束: 499.54 MB
# 构建数据集开始: 499.54 MB
# 构建数据集结束: 499.54 MB
# 构建数据集开始: 499.54 MB
# 构建数据集结束: 499.54 MB
# 构建数据集开始: 499.54 MB
# 构建数据集结束: 499.54 MB
# traverse_tree: Memory Usage: 499.54 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child开始: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建embedding child结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# 构建数据集开始: 499.59 MB
# 构建数据集结束: 499.59 MB
# traverse_tree: Memory Usage: 499.59 MB
# 构建embedding child开始: 499.64 MB
# 构建embedding child结束: 499.64 MB
# 构建embedding child开始: 499.64 MB
# 构建embedding child结束: 499.64 MB
# 构建embedding child开始: 499.64 MB
# 构建embedding child结束: 499.64 MB
# 构建embedding child开始: 499.64 MB
# 构建embedding child结束: 499.64 MB
# 构建embedding child开始: 499.64 MB
# 构建embedding child结束: 499.64 MB
# 构建embedding child开始: 499.64 MB
# 构建embedding child结束: 499.64 MB
# 构建数据集开始: 499.64 MB
# 构建数据集结束: 499.64 MB
# 构建数据集开始: 499.64 MB
# 构建数据集结束: 499.64 MB
# 构建数据集开始: 499.64 MB
# 构建数据集结束: 499.64 MB
# 构建数据集开始: 499.64 MB
# 构建数据集结束: 499.64 MB
# 构建数据集开始: 499.64 MB
# 构建数据集结束: 499.64 MB
# 构建数据集开始: 499.64 MB
# 构建数据集结束: 499.64 MB
# 构建数据集开始: 499.64 MB
# 构建数据集结束: 499.64 MB
# traverse_tree: Memory Usage: 499.64 MB
# 构建embedding child开始: 499.70 MB
# 构建embedding child结束: 499.70 MB
# 构建embedding child开始: 499.70 MB
# 构建embedding child结束: 499.70 MB
# 构建embedding child开始: 499.70 MB
# 构建embedding child结束: 499.70 MB
# 构建embedding child开始: 499.70 MB
# 构建embedding child结束: 499.70 MB
# 构建embedding child开始: 499.70 MB
# 构建embedding child结束: 499.70 MB
# 构建embedding child开始: 499.70 MB
# 构建embedding child结束: 499.70 MB
# 构建数据集开始: 499.70 MB
# 构建数据集结束: 499.70 MB
# 构建数据集开始: 499.70 MB
# 构建数据集结束: 499.70 MB
# 构建数据集开始: 499.70 MB
# 构建数据集结束: 499.70 MB
# 构建数据集开始: 499.70 MB
# 构建数据集结束: 499.70 MB
# 构建数据集开始: 499.70 MB
# 构建数据集结束: 499.70 MB
# 构建数据集开始: 499.70 MB
# 构建数据集结束: 499.70 MB
# 构建数据集开始: 499.70 MB
# 构建数据集结束: 499.70 MB
# traverse_tree: Memory Usage: 499.70 MB
# 构建embedding child开始: 499.75 MB
# 构建embedding child结束: 499.75 MB
# 构建embedding child开始: 499.75 MB
# 构建embedding child结束: 499.75 MB
# 构建embedding child开始: 499.75 MB
# 构建embedding child结束: 499.75 MB
# 构建embedding child开始: 499.75 MB
# 构建embedding child结束: 499.75 MB
# 构建embedding child开始: 499.75 MB
# 构建embedding child结束: 499.75 MB
# 构建embedding child开始: 499.75 MB
# 构建embedding child结束: 499.75 MB
# 构建embedding child开始: 499.75 MB
# 构建embedding child结束: 499.75 MB
# 构建embedding child开始: 499.75 MB
# 构建embedding child结束: 499.75 MB
# 构建数据集开始: 499.75 MB
# 构建数据集结束: 499.75 MB
# 构建数据集开始: 499.75 MB
# 构建数据集结束: 499.75 MB
# 构建数据集开始: 499.75 MB
# 构建数据集结束: 499.75 MB
# 构建数据集开始: 499.75 MB
# 构建数据集结束: 499.75 MB
# 构建数据集开始: 499.75 MB
# 构建数据集结束: 499.75 MB
# 构建数据集开始: 499.75 MB
# 构建数据集结束: 499.75 MB
# 构建数据集开始: 499.75 MB
# 构建数据集结束: 499.75 MB
# 构建数据集开始: 499.75 MB
# 构建数据集结束: 499.75 MB
# 构建数据集开始: 499.75 MB
# 构建数据集结束: 499.75 MB
# traverse_tree: Memory Usage: 499.75 MB
# 构建embedding child开始: 499.82 MB
# 构建embedding child结束: 499.82 MB
# 构建embedding child开始: 499.82 MB
# 构建embedding child结束: 499.82 MB
# 构建数据集开始: 499.82 MB
# 构建数据集结束: 499.82 MB
# 构建数据集开始: 499.82 MB
# 构建数据集结束: 499.82 MB
# 构建数据集开始: 499.82 MB
# 构建数据集结束: 499.82 MB
# traverse_tree: Memory Usage: 499.82 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建embedding child开始: 499.90 MB
# 构建embedding child结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# 构建数据集开始: 499.90 MB
# 构建数据集结束: 499.90 MB
# traverse_tree: Memory Usage: 499.90 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建embedding child开始: 500.01 MB
# 构建embedding child结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# 构建数据集开始: 500.01 MB
# 构建数据集结束: 500.01 MB
# traverse_tree: Memory Usage: 500.01 MB
# 构建embedding child开始: 500.10 MB
# 构建embedding child结束: 500.10 MB
# 构建embedding child开始: 500.10 MB
# 构建embedding child结束: 500.10 MB
# 构建embedding child开始: 500.10 MB
# 构建embedding child结束: 500.10 MB
# 构建embedding child开始: 500.10 MB
# 构建embedding child结束: 500.10 MB
# 构建embedding child开始: 500.10 MB
# 构建embedding child结束: 500.10 MB
# 构建embedding child开始: 500.10 MB
# 构建embedding child结束: 500.10 MB
# 构建embedding child开始: 500.10 MB
# 构建embedding child结束: 500.10 MB
# 构建embedding child开始: 500.10 MB
# 构建embedding child结束: 500.10 MB
# 构建embedding child开始: 500.10 MB
# 构建embedding child结束: 500.10 MB
# 构建embedding child开始: 500.10 MB
# 构建embedding child结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# 构建数据集开始: 500.10 MB
# 构建数据集结束: 500.10 MB
# traverse_tree: Memory Usage: 500.10 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建embedding child开始: 500.20 MB
# 构建embedding child结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# 构建数据集开始: 500.20 MB
# 构建数据集结束: 500.20 MB
# traverse_tree: Memory Usage: 500.20 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建embedding child开始: 500.29 MB
# 构建embedding child结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.29 MB
# 构建数据集开始: 500.29 MB
# 构建数据集结束: 500.31 MB
# traverse_tree: Memory Usage: 500.31 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.70 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.71 MB
# 构建embedding child开始: 500.73 MB
# 构建embedding child开始: 500.73 MB
# 构建embedding child开始: 500.73 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.80 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.86 MB
# 构建embedding child开始: 500.86 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.93 MB
# 构建embedding child开始: 500.93 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.99 MB
# 构建embedding child开始: 500.99 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 500.92 MB
# 构建embedding child开始: 500.92 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.28 MB
# 构建embedding child开始: 501.28 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# 构建embedding child结束: 501.34 MB
# 构建embedding child开始: 501.34 MB
# ...
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# 构建数据集开始: 2184.85 MB
# 构建数据集结束: 2184.85 MB
# traverse_tree: Memory Usage: 2184.85 MB
# 构建embedding child开始: 2188.51 MB
# 构建embedding child结束: 2188.51 MB
# 构建embedding child开始: 2188.51 MB
# 构建embedding child结束: 2188.51 MB
# 构建embedding child开始: 2188.51 MB
# 构建embedding child结束: 2188.51 MB
# 构建embedding child开始: 2188.51 MB
# 构建embedding child结束: 2188.51 MB
# 构建embedding child开始: 2188.51 MB
# 构建embedding child结束: 2188.51 MB
# 构建embedding child开始: 2188.51 MB
# 构建embedding child结束: 2188.51 MB
# 构建embedding child开始: 2188.51 MB
# 构建embedding child结束: 2188.51 MB
# 构建embedding child开始: 2188.51 MB
# 构建embedding child结束: 2188.51 MB
# 构建embedding child开始: 2188.51 MB
# 构建embedding child结束: 2188.51 MB
# 构建embedding child开始: 2188.51 MB
# 构建embedding child结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# 构建数据集开始: 2188.51 MB
# 构建数据集结束: 2188.51 MB
# traverse_tree: Memory Usage: 2188.51 MB
# 构建embedding child开始: 2192.17 MB
# 构建embedding child结束: 2192.17 MB
# 构建embedding child开始: 2192.17 MB
# 构建embedding child结束: 2192.17 MB
# 构建embedding child开始: 2192.17 MB
# 构建embedding child结束: 2192.17 MB
# 构建embedding child开始: 2192.17 MB
# 构建embedding child结束: 2192.17 MB
# 构建embedding child开始: 2192.17 MB
# 构建embedding child结束: 2192.17 MB
# 构建embedding child开始: 2192.17 MB
# 构建embedding child结束: 2192.17 MB
# 构建embedding child开始: 2192.17 MB
# 构建embedding child结束: 2192.17 MB
# 构建数据集开始: 2192.17 MB
# 构建数据集结束: 2192.17 MB
# 构建数据集开始: 2192.17 MB
# 构建数据集结束: 2192.17 MB
# 构建数据集开始: 2192.17 MB
# 构建数据集结束: 2192.17 MB
# 构建数据集开始: 2192.17 MB
# 构建数据集结束: 2192.17 MB
# 构建数据集开始: 2192.17 MB
# 构建数据集结束: 2192.17 MB
# 构建数据集开始: 2192.17 MB
# 构建数据集结束: 2192.17 MB
# 构建数据集开始: 2192.17 MB
# 构建数据集结束: 2192.17 MB
# 构建数据集开始: 2192.17 MB
# 构建数据集结束: 2192.17 MB
# traverse_tree: Memory Usage: 2192.17 MB
# 构建embedding child开始: 2195.84 MB
# 构建embedding child结束: 2195.84 MB
# 构建embedding child开始: 2195.84 MB
# 构建embedding child结束: 2195.84 MB
# 构建embedding child开始: 2195.84 MB
# 构建embedding child结束: 2195.84 MB
# 构建embedding child开始: 2195.84 MB
# 构建embedding child结束: 2195.84 MB
# 构建embedding child开始: 2195.84 MB
# 构建embedding child结束: 2195.84 MB
# 构建embedding child开始: 2195.84 MB
# 构建embedding child结束: 2195.84 MB
# 构建数据集开始: 2195.84 MB
# 构建数据集结束: 2195.84 MB
# 构建数据集开始: 2195.84 MB
# 构建数据集结束: 2195.84 MB
# 构建数据集开始: 2195.84 MB
# 构建数据集结束: 2195.84 MB
# 构建数据集开始: 2195.84 MB
# 构建数据集结束: 2195.84 MB
# 构建数据集开始: 2195.84 MB
# 构建数据集结束: 2195.84 MB
# 构建数据集开始: 2195.84 MB
# 构建数据集结束: 2195.84 MB
# 构建数据集开始: 2195.84 MB
# 构建数据集结束: 2195.84 MB
# traverse_tree: Memory Usage: 2195.84 MB
# 构建embedding child开始: 2199.50 MB
# 构建embedding child结束: 2199.50 MB
# 构建embedding child开始: 2199.50 MB
# 构建embedding child结束: 2199.50 MB
# 构建embedding child开始: 2199.50 MB
# 构建embedding child结束: 2199.50 MB
# 构建embedding child开始: 2199.50 MB
# 构建embedding child结束: 2199.50 MB
# 构建embedding child开始: 2199.50 MB
# 构建embedding child结束: 2199.50 MB
# 构建embedding child开始: 2199.50 MB
# 构建embedding child结束: 2199.50 MB
# 构建数据集开始: 2199.50 MB
# 构建数据集结束: 2199.50 MB
# 构建数据集开始: 2199.50 MB
# 构建数据集结束: 2199.50 MB
# 构建数据集开始: 2199.50 MB
# 构建数据集结束: 2199.50 MB
# 构建数据集开始: 2199.50 MB
# 构建数据集结束: 2199.50 MB
# 构建数据集开始: 2199.50 MB
# 构建数据集结束: 2199.50 MB
# 构建数据集开始: 2199.50 MB
# 构建数据集结束: 2199.50 MB
# 构建数据集开始: 2199.50 MB
# 构建数据集结束: 2199.50 MB
# traverse_tree: Memory Usage: 2199.50 MB
# 构建embedding child开始: 2203.17 MB
# 构建embedding child结束: 2203.17 MB
# 构建embedding child开始: 2203.17 MB
# 构建embedding child结束: 2203.17 MB
# 构建数据集开始: 2203.17 MB
# 构建数据集结束: 2203.17 MB
# 构建数据集开始: 2203.17 MB
# 构建数据集结束: 2203.17 MB
# 构建数据集开始: 2203.17 MB
# 构建数据集结束: 2203.17 MB
# traverse_tree: Memory Usage: 2203.17 MB
# 构建embedding child开始: 2206.84 MB
# 构建embedding child结束: 2207.09 MB
# 构建embedding child开始: 2207.09 MB
# 构建embedding child结束: 2207.09 MB
# 构建embedding child开始: 2207.09 MB
# 构建embedding child结束: 2207.09 MB
# 构建embedding child开始: 2207.09 MB
# 构建embedding child结束: 2207.09 MB
# 构建embedding child开始: 2207.09 MB
# 构建embedding child结束: 2207.09 MB
# 构建embedding child开始: 2207.09 MB
# 构建embedding child结束: 2207.09 MB
# 构建embedding child开始: 2207.09 MB
# 构建embedding child结束: 2207.09 MB
# 构建embedding child开始: 2207.09 MB
# 构建embedding child结束: 2207.09 MB
# 构建数据集开始: 2207.09 MB
# 构建数据集结束: 2207.09 MB
# 构建数据集开始: 2207.09 MB
# 构建数据集结束: 2207.09 MB
# 构建数据集开始: 2207.09 MB
# 构建数据集结束: 2207.09 MB
# 构建数据集开始: 2207.09 MB
# 构建数据集结束: 2207.09 MB
# 构建数据集开始: 2207.09 MB
# 构建数据集结束: 2207.09 MB
# 构建数据集开始: 2207.09 MB
# 构建数据集结束: 2207.09 MB
# 构建数据集开始: 2207.09 MB
# 构建数据集结束: 2207.09 MB
# 构建数据集开始: 2207.09 MB
# 构建数据集结束: 2207.09 MB
# 构建数据集开始: 2207.09 MB
# 构建数据集结束: 2207.09 MB
# traverse_tree: Memory Usage: 2207.09 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建embedding child开始: 2210.76 MB
# 构建embedding child结束: 2210.76 MB
# 构建数据集开始: 2210.76 MB
# 构建数据集结束: 2210.76 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# 构建数据集开始: 2210.80 MB
# 构建数据集结束: 2210.80 MB
# traverse_tree: Memory Usage: 2210.80 MB
# 构建embedding child开始: 2214.73 MB
# 构建embedding child结束: 2214.73 MB
# 构建embedding child开始: 2214.73 MB
# 构建embedding child结束: 2214.73 MB
# 构建embedding child开始: 2214.73 MB
# 构建embedding child结束: 2214.73 MB
# 构建embedding child开始: 2214.73 MB
# 构建embedding child结束: 2214.73 MB
# 构建embedding child开始: 2214.73 MB
# 构建embedding child结束: 2214.73 MB
# 构建embedding child开始: 2214.73 MB
# 构建embedding child结束: 2214.73 MB
# 构建embedding child开始: 2214.73 MB
# 构建embedding child结束: 2214.73 MB
# 构建embedding child开始: 2214.73 MB
# 构建embedding child结束: 2214.73 MB
# 构建embedding child开始: 2214.73 MB
# 构建embedding child结束: 2214.73 MB
# 构建embedding child开始: 2214.73 MB
# 构建embedding child结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# 构建数据集开始: 2214.73 MB
# 构建数据集结束: 2214.73 MB
# traverse_tree: Memory Usage: 2214.73 MB
# 构建embedding child开始: 2218.64 MB
# 构建embedding child结束: 2218.64 MB
# 构建embedding child开始: 2218.64 MB
# 构建embedding child结束: 2218.64 MB
# 构建embedding child开始: 2218.64 MB
# 构建embedding child结束: 2218.64 MB
# 构建embedding child开始: 2218.64 MB
# 构建embedding child结束: 2218.64 MB
# 构建embedding child开始: 2218.64 MB
# 构建embedding child结束: 2218.64 MB
# 构建embedding child开始: 2218.64 MB
# 构建embedding child结束: 2218.64 MB
# 构建embedding child开始: 2218.64 MB
# 构建embedding child结束: 2218.64 MB
# 构建embedding child开始: 2218.64 MB
# 构建embedding child结束: 2218.64 MB
# 构建embedding child开始: 2218.64 MB
# 构建embedding child结束: 2218.64 MB
# 构建embedding child开始: 2218.64 MB
# 构建embedding child结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# 构建数据集开始: 2218.64 MB
# 构建数据集结束: 2218.64 MB
# traverse_tree: Memory Usage: 2218.64 MB
# 构建embedding child开始: 2222.32 MB
# 构建embedding child结束: 2222.32 MB
# 构建embedding child开始: 2222.32 MB
# 构建embedding child结束: 2222.32 MB
# 构建embedding child开始: 2222.32 MB
# 构建embedding child结束: 2222.32 MB
# 构建embedding child开始: 2222.32 MB
# 构建embedding child结束: 2222.32 MB
# 构建embedding child开始: 2222.32 MB
# 构建embedding child结束: 2222.32 MB
# 构建embedding child开始: 2222.32 MB
# 构建embedding child结束: 2222.32 MB
# 构建embedding child开始: 2222.32 MB
# 构建embedding child结束: 2222.57 MB
# 构建embedding child开始: 2222.57 MB
# 构建embedding child结束: 2222.57 MB
# 构建embedding child开始: 2222.57 MB
# 构建embedding child结束: 2222.57 MB
# 构建embedding child开始: 2222.57 MB
# 构建embedding child结束: 2222.57 MB
# 构建embedding child开始: 2222.57 MB
# 构建embedding child结束: 2222.57 MB
# 构建embedding child开始: 2222.57 MB
# 构建embedding child结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# 构建数据集开始: 2222.57 MB
# 构建数据集结束: 2222.57 MB
# traverse_tree: Memory Usage: 2222.57 MB
# 构建embedding child开始: 2226.25 MB
# 构建embedding child结束: 2226.38 MB
# 构建embedding child开始: 2226.38 MB
# 构建embedding child结束: 2226.38 MB
# 构建embedding child开始: 2226.38 MB
# 构建embedding child结束: 2226.38 MB
# 构建embedding child开始: 2226.38 MB
# 构建embedding child结束: 2226.38 MB
# 构建embedding child开始: 2226.38 MB
# 构建embedding child结束: 2226.38 MB
# 构建embedding child开始: 2226.38 MB
# 构建embedding child结束: 2226.38 MB
# 构建数据集开始: 2226.38 MB
# 构建数据集结束: 2226.38 MB
# 构建数据集开始: 2226.38 MB
# 构建数据集结束: 2226.38 MB
# 构建数据集开始: 2226.38 MB
# 构建数据集结束: 2226.38 MB
# 构建数据集开始: 2226.38 MB
# 构建数据集结束: 2226.38 MB
# 构建数据集开始: 2226.38 MB
# 构建数据集结束: 2226.38 MB
# 构建数据集开始: 2226.38 MB
# 构建数据集结束: 2226.38 MB
# 构建数据集开始: 2226.38 MB
# 构建数据集结束: 2226.38 MB
# traverse_tree: Memory Usage: 2226.38 MB
# 构建embedding child开始: 2230.06 MB
# 构建embedding child结束: 2230.06 MB
# 构建embedding child开始: 2230.06 MB
# 构建embedding child结束: 2230.06 MB
# 构建embedding child开始: 2230.06 MB
# 构建embedding child结束: 2230.06 MB
# 构建embedding child开始: 2230.06 MB
# 构建embedding child结束: 2230.06 MB
# 构建embedding child开始: 2230.06 MB
# 构建embedding child结束: 2230.06 MB
# 构建embedding child开始: 2230.06 MB
# 构建embedding child结束: 2230.06 MB
# 构建embedding child开始: 2230.06 MB
# 构建embedding child结束: 2230.06 MB
# 构建数据集开始: 2230.06 MB
# 构建数据集结束: 2230.06 MB
# 构建数据集开始: 2230.06 MB
# 构建数据集结束: 2230.06 MB
# 构建数据集开始: 2230.06 MB
# 构建数据集结束: 2230.06 MB
# 构建数据集开始: 2230.06 MB
# 构建数据集结束: 2230.06 MB
# 构建数据集开始: 2230.06 MB
# 构建数据集结束: 2230.06 MB
# 构建数据集开始: 2230.06 MB
# 构建数据集结束: 2230.06 MB
# 构建数据集开始: 2230.06 MB
# 构建数据集结束: 2230.06 MB
# 构建数据集开始: 2230.06 MB
# 构建数据集结束: 2230.06 MB
# traverse_tree: Memory Usage: 2230.06 MB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\zk\blockGPT\test.ipynb 单元格 3 line 1
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> vocab_size = vocabulary.index + 1
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> d_model = 64
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> build_WordEmbedding(root_node, vocabulary, vocab_size, d_model)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> traverse_tree(root_node, tree_node_list)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> #测试内存代码
#
# c:\zk\blockGPT\test.ipynb 单元格 3 line 1
#     <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=167'>168</a> def build_WordEmbedding(root, vocabulary, vocab_size, d_model):
# --> <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=168'>169</a>     embedding_layer = WordEmbedding(vocab_size, d_model)
#     <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=169'>170</a>     tensor_from_add = torch.rand(1, d_model).unsqueeze(0)  # 对不同from要加上的形状为 (1, 512) 的张量
#     <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=170'>171</a>     tensor_to_add = -tensor_from_add                       # 对不同to要加上的张量#在此处对其加上tree position信息
#
# c:\zk\blockGPT\test.ipynb 单元格 3 line 1
#     <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=134'>135</a> super(WordEmbedding, self).__init__()
#     <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=135'>136</a> self.d_model = d_model
# --> <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=136'>137</a> self.embedding = nn.Embedding(vocab_size, d_model)
#     <a href='vscode-notebook-cell://ssh-remote%2Bgpu/c%3A/zk/blockGPT/test.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=137'>138</a> self.embed = self.embedding
#
# File c:\Users\56844\miniconda3\envs\py38\lib\site-packages\torch\nn\modules\sparse.py:144, in Embedding.__init__(self, num_embeddings, embedding_dim, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse, _weight, _freeze, device, dtype)
#     141 if _weight is None:
#     142     self.weight = Parameter(torch.empty((num_embeddings, embedding_dim), **factory_kwargs),
#     143                             requires_grad=not _freeze)
# --> 144     self.reset_parameters()
#     145 else:
#     146     assert list(_weight.shape) == [num_embeddings, embedding_dim], \
#     147         'Shape of weight does not match num_embeddings and embedding_dim'
#
# File c:\Users\56844\miniconda3\envs\py38\lib\site-packages\torch\nn\modules\sparse.py:153, in Embedding.reset_parameters(self)
#     152 def reset_parameters(self) -> None:
# --> 153     init.normal_(self.weight)
#     154     self._fill_padding_idx_with_zero()
#
# File c:\Users\56844\miniconda3\envs\py38\lib\site-packages\torch\nn\init.py:155, in normal_(tensor, mean, std)
#     153 if torch.overrides.has_torch_function_variadic(tensor):
#     154     return torch.overrides.handle_torch_function(normal_, (tensor,), tensor=tensor, mean=mean, std=std)
# --> 155 return _no_grad_normal_(tensor, mean, std)
#
# File c:\Users\56844\miniconda3\envs\py38\lib\site-packages\torch\nn\init.py:19, in _no_grad_normal_(tensor, mean, std)
#      17 def _no_grad_normal_(tensor, mean, std):
#      18     with torch.no_grad():
# ---> 19         return tensor.normal_(mean, std)
#
# KeyboardInterrupt:
